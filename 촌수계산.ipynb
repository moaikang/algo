# %%
N = int(input())
target1, target2 = map(int, input().split())
M = int(input())
tree = [[0 for _ in range(M + 2)] for range(M)]
count = 0

def dfs(x, y) :
    if x == target1 and y == target2 :
        return
    if x == 
    
    

def calculateRelation() :
    for i in range(tree[target1]) :
        if(tree[target1][i] == 1) :
            dfs(target1, i)
    

for _ in range(M) :
    parent, child = int(input().split())
    tree[parent][child] = 1
    
calculateRelation()
